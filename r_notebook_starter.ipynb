# %% [markdown]
# # R Plotting Notebook
#
# Use this notebook for R code, especially data exploration and plotting with packages like `ggplot2`.
#
# If your R kernel is installed, you can run the code cells directly.

# %%
# Install once if needed
# install.packages(c("ggplot2", "dplyr", "readr"))

library(ggplot2)
library(dplyr)

# %%
# Example plot
df <- data.frame(
  x = 1:10,
  y = c(3, 5, 4, 6, 7, 8, 9, 8, 10, 12)
)

ggplot(df, aes(x, y)) +
  geom_line(linewidth = 1, color = "steelblue") +
  geom_point(size = 2.5, color = "firebrick") +
  labs(title = "Starter R Plot", x = "X", y = "Y") +
  theme_minimal(base_size = 13)

# %%
# Replace this with your own dataset or plotting code
